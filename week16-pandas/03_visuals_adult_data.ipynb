# %% [markdown]
# # load up the adult dataset again

# %%
# make a plot of histograms
# which ones got created? why?

import pandas as pd

# Load data

cols = ['age',
'workclass',
'fnlwgt',
'education',
'education-num',
'marital-status',
'occupation',
'relationship',
'race',
'sex',
'capital-gain',
'capital-loss',
'hours-per-week',
'native-country',
'income']
df = pd.read_csv('adult.csv', names = cols)


histogram = df.hist()

# %%
# adjust the bins

bins_adjusted = df.hist(bins=5)

# %%
# zoom on in the outliers of 'capital gain'

capital_gain = df.hist(column="capital-gain", bins=5, range=(0, 5000))

# %%
# make a correlation plot (look up how we did it in the demo notebook)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = adult_data.select_dtypes(include=['number'])
corr_matrix = numeric_data.corr()
print(corr_matrix)

pd.plotting.scatter_matrix(numeric_data, figsize=(12, 12), diagonal='kde')
plt.suptitle("Scatter Matrix of Numeric Features")
plt.show()
# Out:
#               39     77516        13      2174         0        40
# 39      1.000000 -0.076646  0.036527  0.077674  0.057775  0.068756
#  77516 -0.076646  1.000000 -0.043159  0.000437 -0.010259 -0.018770
#  13     0.036527 -0.043159  1.000000  0.122627  0.079932  0.148127
#  2174   0.077674  0.000437  0.122627  1.000000 -0.031614  0.078409
#  0      0.057775 -0.010259  0.079932 -0.031614  1.000000  0.054256
#  40     0.068756 -0.018770  0.148127  0.078409  0.054256  1.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 9
#       6 corr_matrix = numeric_data.corr()
#       7 print(corr_matrix)
# ----> 9 pd.plotting.scatter_matrix(numeric_data, figsize=(12, 12), diagonal='kde')
#      10 plt.suptitle("Scatter Matrix of Numeric Features")
#      11 plt.show()
#
# ...
