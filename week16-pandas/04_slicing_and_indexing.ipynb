# %% [markdown]
# # load up the adult dataset again

# %%
# select the first 10 rows and the first 3 columns


cols = ['age',
'workclass',
'fnlwgt',
'education',
'education-num',
'marital-status',
'occupation',
'relationship',
'race',
'sex',
'capital-gain',
'capital-loss',
'hours-per-week',
'native-country',
'income']
df = pd.read_csv('adult.csv', names = cols)

result = df.iloc[:10, :3]
print(result)
# Out:
#    age          workclass  fnlwgt
# 0   39          State-gov   77516
# 1   50   Self-emp-not-inc   83311
# 2   38            Private  215646
# 3   53            Private  234721
# 4   28            Private  338409
# 5   37            Private  284582
# 6   49            Private  160187
# 7   52   Self-emp-not-inc  209642
# 8   31            Private   45781
# 9   42            Private  159449

# %%
# select the 20-25th row and 3-5 column

result = df.iloc[20:26, 3:6]
print(result)
# Out:
#      education  education-num       marital-status
# 20   Doctorate             16   Married-civ-spouse
# 21     HS-grad              9            Separated
# 22         9th              5   Married-civ-spouse
# 23        11th              7   Married-civ-spouse
# 24     HS-grad              9             Divorced
# 25   Bachelors             13   Married-civ-spouse

# %%
# select the first 20 rows and the following three columns
# cols: relationship, capital-gain, education

result = df.iloc[:20, [5, 10, 3]]
print(result)
# Out:
#             marital-status  capital-gain      education
# 0            Never-married          2174      Bachelors
# 1       Married-civ-spouse             0      Bachelors
# 2                 Divorced             0        HS-grad
# 3       Married-civ-spouse             0           11th
# 4       Married-civ-spouse             0      Bachelors
# 5       Married-civ-spouse             0        Masters
# 6    Married-spouse-absent             0            9th
# 7       Married-civ-spouse             0        HS-grad
# 8            Never-married         14084        Masters
# 9       Married-civ-spouse          5178      Bachelors
# 10      Married-civ-spouse             0   Some-college
# 11      Married-civ-spouse             0      Bachelors
# 12           Never-married             0      Bachelors
# 13           Never-married             0     Assoc-acdm
# 14      Married-civ-spouse             0      Assoc-voc
# 15      Married-civ-spouse             0        7th-8th
# 16           Never-married             0        HS-grad
# 17           Never-married             0        HS-grad
# 18      Married-civ-spouse             0           11th
# 19                Divorced             0        Masters

# %%
# create a new column which is 
# 2 times the size of the education column

new_column = df['education'] * 2
df['new_column'] = new_column
print(df.head())
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#              new_column
# 0   Bachelors Bachelors
# 1   Bachelors Bachelors
# 2       HS-grad HS-grad
# 3             11th 11th
# 4   Bachelors Bachelors

# %%
# remove that column you just created

df.drop('new_column', axis=1, inplace=True)
print(df.head())
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# create a new row and fill it with the appropriate kind of data for each position

new_row = {
    'age': 30,
    'workclass': 'Private',
    'fnlwgt': 123456,
    'education': 'Bachelors',
    'education-num': 13,
    'marital-status': 'Never-married',
    'occupation': 'Tech-support',
    'relationship': 'Not-in-family',
    'race': 'White',
    'sex': 'Male',
    'capital-gain': 0,
    'capital-loss': 0,
    'hours-per-week': 40,
    'native-country': 'India',
    'income': '<=50K'
}

df.loc[len(df)] = new_row
print(df.tail())
# Out:
#        age      workclass  fnlwgt  education  education-num  \
# 32557   40        Private  154374    HS-grad              9
# 32558   58        Private  151910    HS-grad              9
# 32559   22        Private  201490    HS-grad              9
# 32560   52   Self-emp-inc  287927    HS-grad              9
# 32561   30        Private  123456  Bachelors             13
#
#             marital-status          occupation   relationship    race  \
# 32557   Married-civ-spouse   Machine-op-inspct        Husband   White
# 32558              Widowed        Adm-clerical      Unmarried   White
# 32559        Never-married        Adm-clerical      Own-child   White
# 32560   Married-civ-spouse     Exec-managerial           Wife   White
# 32561        Never-married        Tech-support  Not-in-family   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
# 32561     Male             0             0              40           India
#
#        income
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
# 32561   <=50K

# %%
#select every other row + column

df_every_other = df.iloc[::2, ::2]
print(df_every_other.head())
# Out:
#    age  fnlwgt  education-num          occupation    race  capital-gain  \
# 0   39   77516             13        Adm-clerical   White          2174
# 2   38  215646              9   Handlers-cleaners   White             0
# 4   28  338409             13      Prof-specialty   Black             0
# 6   49  160187              5       Other-service   Black             0
# 8   31   45781             14      Prof-specialty   White         14084
#
#    hours-per-week  income
# 0              40   <=50K
# 2              40   <=50K
# 4              40   <=50K
# 6              16   <=50K
# 8              50    >50K
